# %%
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier,plot_tree
import matplotlib.pyplot as plt
data={
    'sore_throat':[1,0,1,1,0,0,1,0,1,1],
    'fever':[1,0,0,0,1,0,0,1,1,1],
    'swollen_glans':[1,0,1,0,0,0,1,0,0,0],
    'congestion':[1,1,0,0,1,1,0,1,1,1],
    'headache':[1,1,0,0,0,0,0,1,1,1],
    'diagnosis':['Strep_Thorat','Allergy','Cold','Strep_Thorat','Cold','Allergy','Strep_Thorat','Allergy','Cold','Cold']
}
df=pd.DataFrame(data)
print(df)
# Out:
#    sore_throat  fever  swollen_glans  congestion  headache     diagnosis
# 0            1      1              1           1         1  Strep_Thorat
# 1            0      0              0           1         1       Allergy
# 2            1      0              1           0         0          Cold
# 3            1      0              0           0         0  Strep_Thorat
# 4            0      1              0           1         0          Cold
# 5            0      0              0           1         0       Allergy
# 6            1      0              1           0         0  Strep_Thorat
# 7            0      1              0           1         1       Allergy
# 8            1      1              0           1         1          Cold
# 9            1      1              0           1         1          Cold

# %%
X=df[['sore_throat','fever','swollen_glans','congestion','headache']]
y=df['diagnosis']
clf=DecisionTreeClassifier(criterion="entropy")
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
plt.figure(figsize=(12,6))
plot_tree(clf,feature_names=X.columns,class_names=clf.classes_,filled=True,rounded=True,fontsize=10)
plt.show()

# %%
newcase=[[0,0,1,0,0]]
prediction=clf.predict(newcase)
print("Prediction for (0,0,1,0,0):",prediction[0])
# Out:
# Prediction for (0,0,1,0,0): Allergy
# c:\Users\MCA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
