# %% [markdown]
# plotsss

# %%
import matplotlib.pyplot as py
import numpy as np
import seaborn as s

# %%
x = [4,3,2,1.5,1,1.5,2.5,3,4,5,5.5,6.5,7,6.5,6,5,4]
y=[1,2,3,4,5,6,7,6,5,6,7,6,5,4,3,2,1]
# x = np.random.randint(1,100,50)
# y = np.random.randint(1,100,50)
py.plot(x,y,marker='*',color='brown',ms='15',mec= 'black',mfc='yellow')
py.plot(x,y,'o--r')
py.xlabel("Thias is x")
py.ylabel("This")
py.show()

# %%
py.bar(x,y)
py.show()

# %%
py.pie(x)
py.show()

# %%
a = np.arange(3,19)
b = np.arange(3,34,2)
c = np.arange(1,17)
d = np.arange(10,41,2)
# py.plot(a,b,marker='o')
# py.plot(c,d,marker='^')
py.subplot(2,2,1)
py.scatter(a,b)
py.xlabel("As")
py.ylabel("Aswin")
py.title("ASs-Win")
py.grid(color='yellow',linewidth='2')
py.subplot(2,2,4)
py.plot(y,x)
py.xlabel("babs")
py.ylabel("babu")
py.title("Bhavana")
py.grid(color='b',linewidth='2')
py.subplot(2,2,3)
py.bar(a,b)
py.grid(color='blue',linewidth='2')
py.subplot(2,2,2)
py.plot(x,y)
py.grid(color='brown',linewidth='2')
py.suptitle("Bhavana is the BEST")
py.show()

# %%
bmi = np.random.randint(23,346,20)
age = np.random.randint(20,80,20)
sugar = np.array(['high','low','low','mid','high','high','low','low','mid','high','mid','high','high','low','low','mid','high','mid','high','high'])
py.subplot(2,2,1)
py.scatter(bmi,age)
py.subplot(2,2,2)
py.plot(bmi,age)
py.subplot(2,2,3)
py.plot(age,bmi)
py.subplot(2,2,4)
py.bar(age,bmi)
py.show()

# %%
s.scatterplot(x = bmi, y = age, hue=sugar, palette={'high':'red', 'mid':'yellow','low':'green'})
# Out:
# C:\Users\MCA\AppData\Local\Temp\ipykernel_6900\4187928606.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   s.scatterplot(x = x, y = y, palette={'high':'red', 'mid':'yellow','low':'green'})
# <Axes: >
